# %% [markdown]
# # Extracción de Issues Detallados desde SonarCloud
#
# Este notebook está diseñado para extraer todos los issues (problemas) detallados de los proyectos de SonarCloud de los estudiantes, proporcionando un análisis profundo de la calidad del código a nivel de issue individual.
#
# ## Objetivos:
# 1. **Cargar datos** de proyectos de estudiantes desde el CSV con columnas Sonar_Ap1 y Sonar_Ap2
# 2. **Extraer issues detallados** desde SonarCloud API para cada proyecto utilizando `/api/issues/search`
# 3. **Procesar y categorizar** issues por severidad, tipo y regla aplicada
# 4. **Generar análisis** de patrones de calidad de código por estudiante y assignment
# 5. **Exportar resultados** para análisis estadísticos posteriores
#
# ## Información Extraída por Issue:
# - **Identificación**: Issue key, project key, regla aplicada
# - **Clasificación**: Severidad (CRITICAL, MAJOR, MINOR, etc.), tipo (BUG, VULNERABILITY, CODE_SMELL)
# - **Localización**: Archivo/componente afectado, línea de código específica
# - **Descripción**: Mensaje detallado del problema detectado
# - **Contexto**: Información del estudiante y assignment (AP1/AP2)
#
# ## Diferencia con el Notebook Anterior:
# - **Enfoque**: Issues individuales vs. métricas agregadas
# - **Granularidad**: Nivel de línea de código vs. nivel de proyecto
# - **Análisis**: Patrones específicos de problemas vs. estadísticas generales
# - **Volumen**: Mayor cantidad de datos detallados por proyecto

# %%
# Instalación de dependencias (ejecutar solo si es necesario)
import subprocess
import sys

def install_package(package):
    """Instalar paquete si no está disponible"""
    try:
        __import__(package)
        print(f"✅ {package} ya está instalado")
    except ImportError:
        print(f"🔄 Instalando {package}...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])
        print(f"✅ {package} instalado exitosamente")

# Lista de paquetes requeridos
required_packages = ['pandas', 'requests']

print("🔧 Verificando e instalando dependencias...")
for package in required_packages:
    install_package(package)

print("✅ Todas las dependencias están listas")
# Out:
# 🔧 Verificando e instalando dependencias...
# ✅ pandas ya está instalado
# ✅ requests ya está instalado
# ✅ Todas las dependencias están listas

# %%
# Importar librerías necesarias
import pandas as pd
import requests
import json
import base64
import time
from datetime import datetime
from typing import Dict, List, Optional
import warnings
import logging
from functools import wraps
warnings.filterwarnings('ignore')

print("✅ Librerías importadas correctamente")
print("📝 Pandas version:", pd.__version__)
print("🌐 Requests disponible para API calls")
print("🕐 Datetime y logging configurados")
# Out:
# ✅ Librerías importadas correctamente
# 📝 Pandas version: 2.3.1
# 🌐 Requests disponible para API calls
# 🕐 Datetime y logging configurados

# %%
# Funciones utilitarias para optimizar el código
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

def timer_decorator(func):
    """Decorador para medir tiempo de ejecución de funciones"""
    @wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        print(f"⏱️  {func.__name__} ejecutado en {end_time - start_time:.2f} segundos")
        return result
    return wrapper

def clean_message_for_csv(message):
    """Limpiar mensaje para formato CSV"""
    if not message:
        return ""
    # Escapar comillas dobles duplicándolas y envolver en comillas
    cleaned = message.replace('"', '""')
    return f'"{cleaned}"'

def safe_divide(numerator, denominator):
    """División segura que evita división por cero"""
    return numerator / denominator if denominator != 0 else 0

def format_percentage(value, total):
    """Formatear porcentaje de manera consistente"""
    return f"{safe_divide(value, total) * 100:.1f}%"

def print_section_header(title, char="=", width=50):
    """Imprimir headers de sección consistentes"""
    print(f"\n{title}")
    print(char * width)

print("🛠️  Funciones utilitarias cargadas")
print("📊 Timer, limpieza de datos y formateo disponibles")
# Out:
# 🛠️  Funciones utilitarias cargadas
# 📊 Timer, limpieza de datos y formateo disponibles

# %% [markdown]
# ## 1. Configuración de la API de SonarCloud
#
# Configuramos los parámetros necesarios para conectarnos a SonarCloud y extraer issues detallados:
#
# - **Token de autenticación**: Credenciales para acceder a la API de SonarCloud
# - **Headers de autenticación**: Configuración básica con base64 encoding
# - **Organización**: Clave de la organización en SonarCloud (`tesisenel`)
# - **Endpoints**: URLs para búsqueda de proyectos e issues
#
# ### Diferencias con Extracción de Métricas:
# - **Endpoint principal**: `/api/issues/search` (vs `/api/measures/component`)
# - **Paginación**: Manejo de grandes volúmenes de issues por proyecto
# - **Filtros**: Capacidad de filtrar por tipo de issue, severidad, estado
# - **Detalle**: Información específica de ubicación (archivo, línea)

# %%
# Configuración de SonarCloud API para extracción de issues
from functools import lru_cache

# Configuración de autenticación (usando el mismo token del notebook anterior)
SONAR_TOKEN = "cc64d7ea652e603cacbc87bbb9c7b550efee7353"
SONAR_BASE_URL = "https://sonarcloud.io/api"
SONAR_ORGANIZATION = "tesisenel"

# Cache para headers de autenticación
@lru_cache(maxsize=1)
def get_auth_headers():
    """Crear headers de autenticación para SonarCloud API (con caché)"""
    auth_string = f"{SONAR_TOKEN}:"
    auth_bytes = auth_string.encode('ascii')
    auth_b64 = base64.b64encode(auth_bytes).decode('ascii')
    
    return {
        'Authorization': f'Basic {auth_b64}',
        'Content-Type': 'application/json'
    }

# Configuración de parámetros de extracción
ISSUES_CONFIG = {
    'page_size': 500,  # Máximo permitido por SonarCloud
    'max_retries': 3,
    'retry_delay': 5.0,
    'batch_delay': 2.0,
    'timeout': 30
}

# Tipos de issues que vamos a extraer
ISSUE_TYPES = ['BUG', 'VULNERABILITY', 'CODE_SMELL']
SEVERITIES = ['BLOCKER', 'CRITICAL', 'MAJOR', 'MINOR', 'INFO']

print("🔐 Configuración de autenticación preparada")
print(f"🏢 Organización: {SONAR_ORGANIZATION}")
print(f"📊 Page size: {ISSUES_CONFIG['page_size']} issues por página")
print(f"🔄 Reintentos: {ISSUES_CONFIG['max_retries']} máximo")
print("✅ Headers de API configurados con caché")
print("⚠️  Token expuesto temporalmente para pruebas")
# Out:
# 🔐 Configuración de autenticación preparada
# 🏢 Organización: tesisenel
# 📊 Page size: 500 issues por página
# 🔄 Reintentos: 3 máximo
# ✅ Headers de API configurados con caché
# ⚠️  Token expuesto temporalmente para pruebas

# %% [markdown]
# ## 2. Carga de Datos de Estudiantes
#
# Cargamos el mismo archivo CSV utilizado en el notebook anterior, que contiene la información de los estudiantes incluyendo las columnas `Sonar_Ap1` y `Sonar_Ap2` con las claves de los proyectos en SonarCloud.
#
# ### Reutilización de Funciones:
# Utilizaremos la misma función `extract_project_keys()` para extraer las claves de proyecto, manteniendo consistencia con el análisis de métricas.

# %%
# Cargar datos de estudiantes (mismo CSV del notebook anterior)
CSV_PATH = "https://raw.githubusercontent.com/TesisEnel/Recopilacion_Datos_CalidadCodigo/refs/heads/main/Estudiantes_2023-2024.csv"

try:
    # Cargar el CSV con información de estudiantes
    df_estudiantes = pd.read_csv(CSV_PATH)
    
    print("📁 Datos de estudiantes cargados exitosamente")
    print(f"👥 Número de estudiantes: {len(df_estudiantes)}")
    print(f"📊 Columnas disponibles: {list(df_estudiantes.columns)}")
    
    # Verificar columnas de SonarCloud
    sonar_columns = [col for col in df_estudiantes.columns if 'Sonar' in col]
    print(f"\n🎯 Columnas de SonarCloud encontradas: {sonar_columns}")
    
    # Contar proyectos no vacíos
    sonar_ap1_count = df_estudiantes['Sonar_Ap1'].notna().sum()
    sonar_ap2_count = df_estudiantes['Sonar_Ap2'].notna().sum()
    
    print(f"📈 Proyectos Sonar_Ap1 disponibles: {sonar_ap1_count}")
    print(f"📈 Proyectos Sonar_Ap2 disponibles: {sonar_ap2_count}")
    print(f"📈 Total de proyectos para análisis de issues: {sonar_ap1_count + sonar_ap2_count}")
    
    # Mostrar muestra de datos
    print(f"\n🔍 Primeras 3 filas:")
    display(df_estudiantes[['ID', 'Estudiante', 'Sonar_Ap1', 'Sonar_Ap2']].head(3))
    
except FileNotFoundError:
    print("❌ Error: No se encontró el archivo CSV")
    print(f"📍 Buscando en: {CSV_PATH}")
except Exception as e:
    print(f"❌ Error al cargar datos: {e}")
# Out:
# 📁 Datos de estudiantes cargados exitosamente
# 👥 Número de estudiantes: 60
# 📊 Columnas disponibles: ['Id', 'Semestre', 'Estudiante', 'Sexo', 'Email', 'Original_Repo_Ap1', 'Original_Repo_Ap2', 'Sonar_Ap1', 'Sonar_Ap2', 'Sonar_Repo_Ap1', 'Sonar_Repo_Ap2']
#
# 🎯 Columnas de SonarCloud encontradas: ['Sonar_Ap1', 'Sonar_Ap2', 'Sonar_Repo_Ap1', 'Sonar_Repo_Ap2']
# 📈 Proyectos Sonar_Ap1 disponibles: 60
# 📈 Proyectos Sonar_Ap2 disponibles: 60
# 📈 Total de proyectos para análisis de issues: 120
#
# 🔍 Primeras 3 filas:
# ❌ Error al cargar datos: "['ID'] not in index"

# %%
# Extraer project keys de SonarCloud (reutilizando función del notebook anterior)
def extract_project_keys(df):
    """
    Extraer todas las claves de proyecto de SonarCloud del DataFrame
    """
    project_keys = []
    
    for index, row in df.iterrows():
        student_id = row.get('ID', f'Student_{index}')
        nombre = row.get('Estudiante', 'Unknown')
        
        # Procesar Sonar_Ap1
        if pd.notna(row['Sonar_Ap1']) and row['Sonar_Ap1'].strip():
            project_keys.append({
                'student_id': student_id,
                'nombre': nombre,
                'project_key': row['Sonar_Ap1'].strip(),
                'assignment': 'AP1',
                'row_index': index
            })
        
        # Procesar Sonar_Ap2
        if pd.notna(row['Sonar_Ap2']) and row['Sonar_Ap2'].strip():
            project_keys.append({
                'student_id': student_id,
                'nombre': nombre,
                'project_key': row['Sonar_Ap2'].strip(),
                'assignment': 'AP2',
                'row_index': index
            })
    
    return project_keys

# Extraer project keys
project_list = extract_project_keys(df_estudiantes)

print(f"🔑 Total de project keys extraídos: {len(project_list)}")

# Mostrar estadísticas por assignment
ap1_count = len([p for p in project_list if p['assignment'] == 'AP1'])
ap2_count = len([p for p in project_list if p['assignment'] == 'AP2'])

print(f"📊 Proyectos AP1: {ap1_count}")
print(f"📊 Proyectos AP2: {ap2_count}")

# Mostrar algunos ejemplos
print("\n🔍 Primeros 5 project keys para análisis de issues:")
for i, project in enumerate(project_list[:5]):
    print(f"  {i+1}. {project['nombre']} - {project['assignment']}: {project['project_key']}")

print(f"\n✅ Proyectos listos para extracción de issues")
# Out:
# 🔑 Total de project keys extraídos: 120
# 📊 Proyectos AP1: 60
# 📊 Proyectos AP2: 60
#
# 🔍 Primeros 5 project keys para análisis de issues:
#   1. Aaron Eliezer Hernández García - AP1: TesisEnel_SwiftPay-Aaron-Ap1
#   2. Aaron Eliezer Hernández García - AP2: TesisEnel_DealerPOS-Aaron-ap2
#   3. Abraham El Hage Jreij - AP1: TesisEnel_AguaMariaSolution-JulioPichardo-ap1
#   4. Abraham El Hage Jreij - AP2: TesisEnel_Final_Project-Abraham-ap2
#   5. Adiel Luis García Rosa - AP1: TesisEnel_PeakPerformance-samuelAntonio-ap1
#
# ✅ Proyectos listos para extracción de issues

# %% [markdown]
# ## 3. Implementación de Funciones de Extracción de Issues
#
# Implementamos las funciones principales para extraer issues detallados de SonarCloud utilizando el endpoint `/api/issues/search`.
#
# ### Funciones implementadas:
#
# #### `fetch_project_issues(project_key)`
# - **Propósito**: Obtener todos los issues de un proyecto específico desde SonarCloud
# - **Endpoint**: `/api/issues/search`
# - **Características**:
#   - ⏱️ **Timing con decorador**: Mide tiempo de ejecución
#   - 🔄 **Paginación automática**: Maneja múltiples páginas de resultados
#   - 🛡️ **Manejo robusto de errores**: Captura errores HTTP, conexión y timeout
#   - 📊 **Extracción completa**: Obtiene todos los campos relevantes del issue
#   - 📝 **Logging estructurado**: Registra progreso y errores
#
# #### `batch_fetch_issues(project_list)`
# - **Propósito**: Procesar múltiples proyectos con control de rate limiting
# - **Características**:
#   - ⚡ **Procesamiento secuencial**: Evita sobrecargar la API
#   - 📊 **Progreso en tiempo real**: Indicadores de avance por proyecto
#   - 🎯 **Estadísticas detalladas**: Conteo de issues por proyecto
#   - ⏳ **Rate limiting**: Delays configurables entre proyectos
#   - 🛡️ **Tolerancia a fallos**: Continúa aunque fallen proyectos individuales
#
# #### Funciones auxiliares:
# - `parse_issue_data()`: Extrae y estructura datos del issue
# - `create_issue_error_response()`: Respuestas de error estandarizadas

# %%
# Funciones para extraer issues de SonarCloud API

def parse_issue_data(issue, project_info):
    """Extraer y estructurar datos de un issue individual"""
    return {
        # Información del proyecto y estudiante
        'student_id': project_info['student_id'],
        'nombre': project_info['nombre'],
        'assignment': project_info['assignment'],
        'row_index': project_info['row_index'],
        'project_key': project_info['project_key'],
        
        # Información del issue
        'issue_key': issue.get('key', ''),
        'rule': issue.get('rule', ''),
        'severity': issue.get('severity', ''),
        'type': issue.get('type', ''),
        'message': issue.get('message', ''),
        'component': issue.get('component', ''),
        'line': issue.get('line', 0),
        'status': issue.get('status', ''),
        'creation_date': issue.get('creationDate', ''),
        'update_date': issue.get('updateDate', ''),
        'effort': issue.get('effort', ''),
        'debt': issue.get('debt', ''),
        'tags': ','.join(issue.get('tags', [])) if issue.get('tags') else ''
    }

def create_issue_error_response(project_key, status, error_info=None):
    """Crear respuesta de error estandarizada para issues"""
    response = {
        'project_key': project_key, 
        'status': status,
        'issues_count': 0,
        'issues': []
    }
    if error_info:
        response['error'] = error_info
    return response

@timer_decorator
def fetch_project_issues(project_info: Dict, retries: int = 3, delay: float = 5.0) -> Dict:
    """
    Obtener todos los issues de un proyecto específico desde SonarCloud con paginación
    """
    project_key = project_info['project_key']
    all_issues = []
    page = 1
    has_more_pages = True
    
    while has_more_pages:
        url = f"{SONAR_BASE_URL}/issues/search"
        params = {
            'componentKeys': project_key,
            'p': page,
            'ps': ISSUES_CONFIG['page_size']
        }
        
        for attempt in range(retries):
            try:
                response = requests.get(
                    url, 
                    params=params, 
                    headers=get_auth_headers(), 
                    timeout=ISSUES_CONFIG['timeout']
                )
                
                if response.status_code == 200:
                    data = response.json()
                    
                    # Extraer issues de esta página
                    if 'issues' in data and data['issues']:
                        page_issues = [
                            parse_issue_data(issue, project_info) 
                            for issue in data['issues']
                        ]
                        all_issues.extend(page_issues)
                    
                    # Verificar si hay más páginas
                    paging = data.get('paging', {})
                    total = paging.get('total', 0)
                    page_size = paging.get('pageSize', ISSUES_CONFIG['page_size'])
                    
                    has_more_pages = (page * page_size) < total
                    if has_more_pages:
                        page += 1
                        print(f"    📄 Página {page-1} procesada, {len(page_issues)} issues encontrados")
                    else:
                        print(f"    📄 Página {page} procesada (final), {len(page_issues)} issues encontrados")
                    
                    break  # Salir del loop de reintentos
                    
                elif response.status_code == 401:
                    logger.warning(f"Authentication error for project {project_key}")
                    if attempt == retries - 1:
                        return create_issue_error_response(project_key, 'authentication_error', response.status_code)
                else:
                    logger.warning(f"HTTP error {response.status_code} for project {project_key}")
                    if attempt == retries - 1:
                        return create_issue_error_response(project_key, f'http_error_{response.status_code}', response.status_code)
                
                time.sleep(delay)
                
            except requests.exceptions.RequestException as e:
                logger.error(f"Connection error for project {project_key}: {e}")
                if attempt == retries - 1:
                    return create_issue_error_response(project_key, 'connection_error', str(e))
                time.sleep(delay)
            except Exception as e:
                logger.error(f"Unexpected error for project {project_key}: {e}")
                if attempt == retries - 1:
                    return create_issue_error_response(project_key, 'unexpected_error', str(e))
                time.sleep(delay)
    
    return {
        'project_key': project_key,
        'status': 'success',
        'issues_count': len(all_issues),
        'issues': all_issues
    }

@timer_decorator  
def batch_fetch_issues(project_list: List[Dict]) -> List[Dict]:
    """
    Obtener issues para múltiples proyectos con control de rate limiting
    """
    results = []
    total_projects = len(project_list)
    total_issues = 0
    
    print_section_header(f"🚀 Extracción de issues para {total_projects} proyectos")
    
    for i, project in enumerate(project_list, 1):
        project_key = project['project_key']
        print(f"\n📦 Proyecto {i}/{total_projects}: {project['nombre']} - {project['assignment']}")
        print(f"🔄 Procesando: {project_key}")
        
        # Extraer issues del proyecto
        result = fetch_project_issues(project)
        
        # Agregar información del estudiante al resultado
        result.update({
            'student_id': project['student_id'],
            'nombre': project['nombre'],
            'assignment': project['assignment'],
            'row_index': project['row_index']
        })
        
        results.append(result)
        
        # Mostrar resultado
        if result['status'] == 'success':
            issues_count = result['issues_count']
            total_issues += issues_count
            print(f"    ✅ {issues_count} issues extraídos exitosamente")
        else:
            print(f"    ❌ Error: {result.get('status', 'unknown')}")
        
        # Progress update
        progress = i / total_projects * 100
        print(f"    📊 Progreso: {progress:.1f}% ({i}/{total_projects})")
        
        # Delay entre proyectos para respetar rate limits
        if i < total_projects:
            print(f"    ⏳ Esperando {ISSUES_CONFIG['batch_delay']}s...")
            time.sleep(ISSUES_CONFIG['batch_delay'])
    
    # Estadísticas finales
    successful = [r for r in results if r.get('status') == 'success']
    print_section_header("📈 Estadísticas de Extracción de Issues")
    print(f"✅ Proyectos exitosos: {len(successful)} ({format_percentage(len(successful), total_projects)})")
    print(f"❌ Proyectos fallidos: {total_projects - len(successful)} ({format_percentage(total_projects - len(successful), total_projects)})")
    print(f"📊 Total de issues extraídos: {total_issues}")
    
    return results

print("🛠️  Funciones de extracción de issues configuradas")
print("📡 Listo para extraer issues detallados con paginación automática")
# Out:
# 🛠️  Funciones de extracción de issues configuradas
# 📡 Listo para extraer issues detallados con paginación automática

# %% [markdown]
# ## 4. Ejecución del Proceso de Extracción de Issues
#
# Ejecutamos el proceso de extracción de issues para todos los proyectos de estudiantes. Este proceso puede tomar considerablemente más tiempo que la extracción de métricas debido al volumen de datos por proyecto.
#
# ### Configuración del proceso:
# - **Paginación**: 500 issues por página (máximo de SonarCloud)
# - **Rate limiting**: 2.0 segundos entre proyectos
# - **Reintentos**: 3 intentos por proyecto en caso de errores
# - **Timeout**: 30 segundos por request
#
# ### Monitoreo incluido:
# - ✅ **Progreso por proyecto**: Estudiante, assignment y project key
# - 📄 **Progreso por página**: Número de issues por página procesada
# - 📊 **Contadores en tiempo real**: Issues extraídos por proyecto
# - ⏱️ **Tiempo de ejecución**: Por proyecto y total
# - 🔍 **Detección de errores**: Logging de errores específicos
#
# > **Nota**: La extracción puede tomar varios minutos dependiendo de la cantidad de issues por proyecto. Proyectos con muchos issues requerirán múltiples páginas.

# %%
# Ejecutar extracción de issues
print("🚀 Iniciando proceso de extracción de issues detallados...")
print(f"📊 Total de proyectos a procesar: {len(project_list)}")
print(f"⚙️  Configuración: {ISSUES_CONFIG['page_size']} issues por página, {ISSUES_CONFIG['batch_delay']}s entre proyectos")

# Ejecutar extracción
issues_results = batch_fetch_issues(project_list)

print("\n📈 Resultados de la extracción de issues:")
print(f"✅ Total de proyectos procesados: {len(issues_results)}")

# Analizar resultados
successful_extractions = [r for r in issues_results if r.get('status') == 'success']
failed_extractions = [r for r in issues_results if r.get('status') != 'success']

print(f"✅ Extracciones exitosas: {len(successful_extractions)}")
print(f"❌ Extracciones fallidas: {len(failed_extractions)}")

# Calcular totales de issues
total_issues = sum(r.get('issues_count', 0) for r in successful_extractions)
print(f"📊 Total de issues extraídos: {total_issues}")

if failed_extractions:
    print("\n⚠️  Proyectos con errores:")
    for failed in failed_extractions[:5]:  # Mostrar solo los primeros 5
        print(f"  - {failed['project_key']}: {failed.get('status', 'unknown error')}")

# Mostrar estadísticas por assignment
ap1_projects = [r for r in successful_extractions if r.get('assignment') == 'AP1']
ap2_projects = [r for r in successful_extractions if r.get('assignment') == 'AP2']

ap1_issues = sum(r.get('issues_count', 0) for r in ap1_projects)
ap2_issues = sum(r.get('issues_count', 0) for r in ap2_projects)

print(f"\n📊 Distribución por assignment:")
print(f"  AP1: {len(ap1_projects)} proyectos, {ap1_issues} issues")
print(f"  AP2: {len(ap2_projects)} proyectos, {ap2_issues} issues")

# Mostrar ejemplo de issues extraídos
if successful_extractions and total_issues > 0:
    # Buscar el primer proyecto con issues
    example_project = None
    for project in successful_extractions:
        if project.get('issues_count', 0) > 0:
            example_project = project
            break
    
    if example_project:
        print(f"\n🔍 Ejemplo de issues extraídos (proyecto: {example_project['project_key']}):")
        print(f"Estudiante: {example_project['nombre']}")
        print(f"Assignment: {example_project['assignment']}")
        print(f"Total de issues: {example_project['issues_count']}")
        
        # Mostrar primeros 3 issues
        sample_issues = example_project['issues'][:3]
        for i, issue in enumerate(sample_issues, 1):
            print(f"\n  Issue {i}:")
            print(f"    Tipo: {issue['type']}")
            print(f"    Severidad: {issue['severity']}")
            print(f"    Regla: {issue['rule']}")
            print(f"    Línea: {issue['line']}")
            print(f"    Mensaje: {issue['message'][:100]}{'...' if len(issue['message']) > 100 else ''}")

print("\n✅ Extracción de issues completada")
# Out:
# 🚀 Iniciando proceso de extracción de issues detallados...
# 📊 Total de proyectos a procesar: 120
# ⚙️  Configuración: 500 issues por página, 2.0s entre proyectos
#
# 🚀 Extracción de issues para 120 proyectos
# ==================================================
#
# 📦 Proyecto 1/120: Aaron Eliezer Hernández García - AP1
# 🔄 Procesando: TesisEnel_SwiftPay-Aaron-Ap1
#     📄 Página 1 procesada (final), 249 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.77 segundos
#     ✅ 249 issues extraídos exitosamente
#     📊 Progreso: 0.8% (1/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 2/120: Aaron Eliezer Hernández García - AP2
# 🔄 Procesando: TesisEnel_DealerPOS-Aaron-ap2
#     📄 Página 1 procesada (final), 241 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.63 segundos
#     ✅ 241 issues extraídos exitosamente
#     📊 Progreso: 1.7% (2/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 3/120: Abraham El Hage Jreij - AP1
# 🔄 Procesando: TesisEnel_AguaMariaSolution-JulioPichardo-ap1
#     📄 Página 1 procesada (final), 47 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.66 segundos
#     ✅ 47 issues extraídos exitosamente
#     📊 Progreso: 2.5% (3/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 4/120: Abraham El Hage Jreij - AP2
# 🔄 Procesando: TesisEnel_Final_Project-Abraham-ap2
#     📄 Página 1 procesada (final), 37 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.47 segundos
#     ✅ 37 issues extraídos exitosamente
#     📊 Progreso: 3.3% (4/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 5/120: Adiel Luis García Rosa - AP1
# 🔄 Procesando: TesisEnel_PeakPerformance-samuelAntonio-ap1
#     📄 Página 1 procesada (final), 56 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.62 segundos
#     ✅ 56 issues extraídos exitosamente
#     📊 Progreso: 4.2% (5/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 6/120: Adiel Luis García Rosa - AP2
# 🔄 Procesando: TesisEnel_GymProApp-AdielGarcia-Ap2
#     📄 Página 1 procesada (final), 40 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.58 segundos
#     ✅ 40 issues extraídos exitosamente
#     📊 Progreso: 5.0% (6/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 7/120: Alaina Garcia Salazar - AP1
# 🔄 Procesando: TesisEnel_ReyAI_Transport-Reyfil-Ap1
#     📄 Página 1 procesada (final), 35 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.65 segundos
#     ✅ 35 issues extraídos exitosamente
#     📊 Progreso: 5.8% (7/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 8/120: Alaina Garcia Salazar - AP2
# 🔄 Procesando: TesisEnel_RecreArte-JeronyCruz-Ap2
#     📄 Página 1 procesada (final), 116 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.47 segundos
#     ✅ 116 issues extraídos exitosamente
#     📊 Progreso: 6.7% (8/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 9/120: Albert Luis Delgado Maria - AP1
# 🔄 Procesando: TesisEnel_ProyectoFinal-AlbertRegalado-ap1
#     📄 Página 1 procesada (final), 72 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.63 segundos
#     ✅ 72 issues extraídos exitosamente
#     📊 Progreso: 7.5% (9/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 10/120: Albert Luis Delgado Maria - AP2
# 🔄 Procesando: TesisEnel_MoonlightBarApp-AlbetDelgado-ap2
#     📄 Página 1 procesada (final), 28 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.83 segundos
#     ✅ 28 issues extraídos exitosamente
#     📊 Progreso: 8.3% (10/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 11/120: Alexander Suárez - AP1
# 🔄 Procesando: TesisEnel_ProyectoFinalDotNet8-alexander-ap1
#     📄 Página 1 procesada (final), 28 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.53 segundos
#     ✅ 28 issues extraídos exitosamente
#     📊 Progreso: 9.2% (11/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 12/120: Alexander Suárez - AP2
# 🔄 Procesando: TesisEnel_GeekMarket-Alexander-ap2
#     📄 Página 1 procesada (final), 84 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.50 segundos
#     ✅ 84 issues extraídos exitosamente
#     📊 Progreso: 10.0% (12/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 13/120: Alma Betsaida Rosa - AP1
# 🔄 Procesando: TesisEnel_Proyecto_TixPro-CarlosCustodio-ap1
#     📄 Página 1 procesada (final), 41 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.59 segundos
#     ✅ 41 issues extraídos exitosamente
#     📊 Progreso: 10.8% (13/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 14/120: Alma Betsaida Rosa - AP2
# 🔄 Procesando: TesisEnel_FinTracker-AlmaCocolate-ap2
#     📄 Página 1 procesada (final), 102 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.43 segundos
#     ✅ 102 issues extraídos exitosamente
#     📊 Progreso: 11.7% (14/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 15/120: Angel Luis González Delgado - AP1
# 🔄 Procesando: TesisEnel_ProyectoFinalGourmetGrill-Marte-ap1
#     📄 Página 1 procesada (final), 28 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.56 segundos
#     ✅ 28 issues extraídos exitosamente
#     📊 Progreso: 12.5% (15/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 16/120: Angel Luis González Delgado - AP2
# 🔄 Procesando: TesisEnel_Doers-JoseOrtega-ap2
#     📄 Página 1 procesada (final), 117 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.56 segundos
#     ✅ 117 issues extraídos exitosamente
#     📊 Progreso: 13.3% (16/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 17/120: Braylin Vasquez Guzman - AP1
# 🔄 Procesando: TesisEnel_ProyectoFinalAplicada1-Brailyn-ap1
#     📄 Página 1 procesada (final), 41 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.55 segundos
#     ✅ 41 issues extraídos exitosamente
#     📊 Progreso: 14.2% (17/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 18/120: Braylin Vasquez Guzman - AP2
# 🔄 Procesando: TesisEnel_ProyectoFinalAplicada2-Brailyn-ap2
#     📄 Página 1 procesada (final), 43 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.47 segundos
#     ✅ 43 issues extraídos exitosamente
#     📊 Progreso: 15.0% (18/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 19/120: Bryan Smith Ovalles Burgos - AP1
# 🔄 Procesando: TesisEnel_Proyecto_SouKuroApp-BryanOvalles-Ap1
#     📄 Página 1 procesada (final), 29 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.82 segundos
#     ✅ 29 issues extraídos exitosamente
#     📊 Progreso: 15.8% (19/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 20/120: Bryan Smith Ovalles Burgos - AP2
# 🔄 Procesando: TesisEnel_Doers-JoseOrtega-ap2
#     📄 Página 1 procesada (final), 117 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.50 segundos
#     ✅ 117 issues extraídos exitosamente
#     📊 Progreso: 16.7% (20/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 21/120: Carlos Manuel Custodio Then - AP1
# 🔄 Procesando: TesisEnel_Proyecto_TixPro-CarlosCustodio-ap1
#     📄 Página 1 procesada (final), 41 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.64 segundos
#     ✅ 41 issues extraídos exitosamente
#     📊 Progreso: 17.5% (21/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 22/120: Carlos Manuel Custodio Then - AP2
# 🔄 Procesando: TesisEnel_FinTracker-AlmaCocolate-ap2
#     📄 Página 1 procesada (final), 102 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.46 segundos
#     ✅ 102 issues extraídos exitosamente
#     📊 Progreso: 18.3% (22/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 23/120: Cesar Jose Reynoso Martinez - AP1
# 🔄 Procesando: TesisEnel_ProStellar-Cesar-ap1
#     📄 Página 1 procesada (final), 285 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.78 segundos
#     ✅ 285 issues extraídos exitosamente
#     📊 Progreso: 19.2% (23/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 24/120: Cesar Jose Reynoso Martinez - AP2
# 🔄 Procesando: TesisEnel_FlappyEnel-Cesar-ap2
#     📄 Página 1 procesada (final), 59 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.47 segundos
#     ✅ 59 issues extraídos exitosamente
#     📊 Progreso: 20.0% (24/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 25/120: Cristopher Marte Blanco - AP1
# 🔄 Procesando: TesisEnel_ProyectoFinalGourmetGrill-Marte-ap1
#     📄 Página 1 procesada (final), 28 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.51 segundos
#     ✅ 28 issues extraídos exitosamente
#     📊 Progreso: 20.8% (25/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 26/120: Cristopher Marte Blanco - AP2
# 🔄 Procesando: TesisEnel_Doers-JoseOrtega-ap2
#     📄 Página 1 procesada (final), 117 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.47 segundos
#     ✅ 117 issues extraídos exitosamente
#     📊 Progreso: 21.7% (26/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 27/120: David Otoniel Rosario Serrano - AP1
# 🔄 Procesando: TesisEnel_ProyectoFinalSistemaVentas-davidOtoniel-ap1
#     📄 Página 1 procesada (final), 80 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.64 segundos
#     ✅ 80 issues extraídos exitosamente
#     📊 Progreso: 22.5% (27/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 28/120: David Otoniel Rosario Serrano - AP2
# 🔄 Procesando: TesisEnel_FoodiePlace-David-ap2
#     📄 Página 1 procesada (final), 66 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.52 segundos
#     ✅ 66 issues extraídos exitosamente
#     📊 Progreso: 23.3% (28/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 29/120: Delfry Paulino - AP1
# 🔄 Procesando: TesisEnel_HydraulicFix-Delfry-Ap1
#     📄 Página 1 procesada (final), 24 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.65 segundos
#     ✅ 24 issues extraídos exitosamente
#     📊 Progreso: 24.2% (29/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 30/120: Delfry Paulino - AP2
# 🔄 Procesando: TesisEnel_FitGoal-Delfry-Ap2
#     📄 Página 1 procesada (final), 42 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.61 segundos
#     ✅ 42 issues extraídos exitosamente
#     📊 Progreso: 25.0% (30/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 31/120: Eddy Samil Capellan Mena - AP1
# 🔄 Procesando: TesisEnel_ProyectoFinalAp1-JoseDaniel-ap1
#     📄 Página 1 procesada (final), 33 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.76 segundos
#     ✅ 33 issues extraídos exitosamente
#     📊 Progreso: 25.8% (31/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 32/120: Eddy Samil Capellan Mena - AP2
# 🔄 Procesando: TesisEnel_URESERVE-JoseDaniel-ap2
#     📄 Página 1 procesada (final), 302 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.67 segundos
#     ✅ 302 issues extraídos exitosamente
#     📊 Progreso: 26.7% (32/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 33/120: Eliezer terrero rojas - AP1
# 🔄 Procesando: TesisEnel_ProyectoFinalAplicada1-Brailyn-ap1
#     📄 Página 1 procesada (final), 41 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.74 segundos
#     ✅ 41 issues extraídos exitosamente
#     📊 Progreso: 27.5% (33/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 34/120: Eliezer terrero rojas - AP2
# 🔄 Procesando: TesisEnel_ProyectoFinalAplicada2-Brailyn-ap2
#     📄 Página 1 procesada (final), 43 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.45 segundos
#     ✅ 43 issues extraídos exitosamente
#     📊 Progreso: 28.3% (34/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 35/120: Emill Daniel García Castellanos - AP1
# 🔄 Procesando: TesisEnel_SystemFerreteria-emildaniel-ap1
#     📄 Página 1 procesada (final), 49 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.88 segundos
#     ✅ 49 issues extraídos exitosamente
#     📊 Progreso: 29.2% (35/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 36/120: Emill Daniel García Castellanos - AP2
# 🔄 Procesando: TesisEnel_TRABAJA_YA-EmilGarcia-ap2
#     📄 Página 1 procesada (final), 61 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.41 segundos
#     ✅ 61 issues extraídos exitosamente
#     📊 Progreso: 30.0% (36/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 37/120: Freimy De Jesus Hidalgo Gonzalez - AP1
# 🔄 Procesando: TesisEnel_SkyReserves-FreimyHidalgo-Ap1
#     📄 Página 1 procesada (final), 20 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.65 segundos
#     ✅ 20 issues extraídos exitosamente
#     📊 Progreso: 30.8% (37/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 38/120: Freimy De Jesus Hidalgo Gonzalez - AP2
# 🔄 Procesando: TesisEnel_SkyFleet-FreimyHidaldo-Ap2
#     📄 Página 1 procesada (final), 3 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.81 segundos
#     ✅ 3 issues extraídos exitosamente
#     📊 Progreso: 31.7% (38/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 39/120: Geremy O. de los Santos Santiago - AP1
# 🔄 Procesando: TesisEnel_ControlDeInventarios-GeremySantiago-Ap1
#     📄 Página 1 procesada (final), 21 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.65 segundos
#     ✅ 21 issues extraídos exitosamente
#     📊 Progreso: 32.5% (39/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 40/120: Geremy O. de los Santos Santiago - AP2
# 🔄 Procesando: TesisEnel_SaludConnect-GeremySantiago-Ap2
#     📄 Página 1 procesada (final), 17 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.39 segundos
#     ✅ 17 issues extraídos exitosamente
#     📊 Progreso: 33.3% (40/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 41/120: Greilyn Polanco Tejada - AP1
# 🔄 Procesando: TesisEnel_SalesSyste-Levid-ap1
#     📄 Página 1 procesada (final), 45 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.72 segundos
#     ✅ 45 issues extraídos exitosamente
#     📊 Progreso: 34.2% (41/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 42/120: Greilyn Polanco Tejada - AP2
# 🔄 Procesando: TesisEnel_PuppyPlace-Levid-ap2
#     📄 Página 1 procesada (final), 21 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.77 segundos
#     ✅ 21 issues extraídos exitosamente
#     📊 Progreso: 35.0% (42/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 43/120: Henry milagros Rosario Peña - AP1
# 🔄 Procesando: TesisEnel_ProyectoFinalPA1-Henry-ap1
#     📄 Página 1 procesada (final), 64 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.56 segundos
#     ✅ 64 issues extraídos exitosamente
#     📊 Progreso: 35.8% (43/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 44/120: Henry milagros Rosario Peña - AP2
# 🔄 Procesando: TesisEnel_CuentaXPagarAPP-Henry-ap2
#     📄 Página 1 procesada (final), 29 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.45 segundos
#     ✅ 29 issues extraídos exitosamente
#     📊 Progreso: 36.7% (44/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 45/120: Isaac Patricio Coste Burgos - AP1
# 🔄 Procesando: TesisEnel_ProyectoFinalAp-IsaacCoste-ap1
#     📄 Página 1 procesada (final), 54 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.56 segundos
#     ✅ 54 issues extraídos exitosamente
#     📊 Progreso: 37.5% (45/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 46/120: Isaac Patricio Coste Burgos - AP2
# 🔄 Procesando: TesisEnel_SharkStyle-IsaacCoste-ap2
#     📄 Página 1 procesada (final), 78 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.45 segundos
#     ✅ 78 issues extraídos exitosamente
#     📊 Progreso: 38.3% (46/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 47/120: Jairo Camilo - AP1
# 🔄 Procesando: TesisEnel_MediSoft-JairoAcosta-Ap1
#     📄 Página 1 procesada (final), 39 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.65 segundos
#     ✅ 39 issues extraídos exitosamente
#     📊 Progreso: 39.2% (47/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 48/120: Jairo Camilo - AP2
# 🔄 Procesando: TesisEnel_SpellingAppV2-JairoAcosta-Ap2
#     📄 Página 1 procesada (final), 37 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.75 segundos
#     ✅ 37 issues extraídos exitosamente
#     📊 Progreso: 40.0% (48/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 49/120: Jasson Levid Tejada Martínez - AP1
# 🔄 Procesando: TesisEnel_SalesSyste-Levid-ap1
#     📄 Página 1 procesada (final), 45 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.58 segundos
#     ✅ 45 issues extraídos exitosamente
#     📊 Progreso: 40.8% (49/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 50/120: Jasson Levid Tejada Martínez - AP2
# 🔄 Procesando: TesisEnel_PuppyPlace-Levid-ap2
#     📄 Página 1 procesada (final), 21 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.40 segundos
#     ✅ 21 issues extraídos exitosamente
#     📊 Progreso: 41.7% (50/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 51/120: Jerony Ulises Cruz Fermin - AP1
# 🔄 Procesando: TesisEnel_DragonsDinner-JeronyCruz-Ap1
#     📄 Página 1 procesada (final), 72 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.93 segundos
#     ✅ 72 issues extraídos exitosamente
#     📊 Progreso: 42.5% (51/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 52/120: Jerony Ulises Cruz Fermin - AP2
# 🔄 Procesando: TesisEnel_RecreArte-JeronyCruz-Ap2
#     📄 Página 1 procesada (final), 116 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.53 segundos
#     ✅ 116 issues extraídos exitosamente
#     📊 Progreso: 43.3% (52/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 53/120: Jorge Luis Toribio Gil - AP1
# 🔄 Procesando: TesisEnel_ProyectoFinal-JorgeToribio-Ap1
#     📄 Página 1 procesada (final), 46 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.96 segundos
#     ✅ 46 issues extraídos exitosamente
#     📊 Progreso: 44.2% (53/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 54/120: Jorge Luis Toribio Gil - AP2
# 🔄 Procesando: TesisEnel_VerbLearn-JorgeToribio-Ap2
#     📄 Página 1 procesada (final), 76 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.52 segundos
#     ✅ 76 issues extraídos exitosamente
#     📊 Progreso: 45.0% (54/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 55/120: José Antonio Ortega Serrano - AP1
# 🔄 Procesando: TesisEnel_ProyectoFinalSistemaVentas-davidOtoniel-ap1
#     📄 Página 1 procesada (final), 80 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.58 segundos
#     ✅ 80 issues extraídos exitosamente
#     📊 Progreso: 45.8% (55/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 56/120: José Antonio Ortega Serrano - AP2
# 🔄 Procesando: TesisEnel_Doers-JoseOrtega-ap2
#     📄 Página 1 procesada (final), 117 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.48 segundos
#     ✅ 117 issues extraídos exitosamente
#     📊 Progreso: 46.7% (56/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 57/120: Jose Daniel Rivera Ortega - AP1
# 🔄 Procesando: TesisEnel_ProyectoFinalAp1-JoseDaniel-ap1
#     📄 Página 1 procesada (final), 33 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.66 segundos
#     ✅ 33 issues extraídos exitosamente
#     📊 Progreso: 47.5% (57/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 58/120: Jose Daniel Rivera Ortega - AP2
# 🔄 Procesando: TesisEnel_URESERVE-JoseDaniel-ap2
#     📄 Página 1 procesada (final), 302 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.57 segundos
#     ✅ 302 issues extraídos exitosamente
#     📊 Progreso: 48.3% (58/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 59/120: Jose Manuel Polanco - AP1
# 🔄 Procesando: TesisEnel_PanaderiaMj-JoseManuelPolanco-Ap1
#     📄 Página 1 procesada (final), 28 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.50 segundos
#     ✅ 28 issues extraídos exitosamente
#     📊 Progreso: 49.2% (59/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 60/120: Jose Manuel Polanco - AP2
# 🔄 Procesando: TesisEnel_JSAutoParts-JoseManuelPolanco-Ap2
#     📄 Página 1 procesada (final), 67 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.41 segundos
#     ✅ 67 issues extraídos exitosamente
#     📊 Progreso: 50.0% (60/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 61/120: Jose Miguel Bonilla - AP1
# 🔄 Procesando: TesisEnel_PrestigeFinancialManager-JoseMiguelBonilla-Ap1
#     📄 Página 1 procesada (final), 109 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.61 segundos
#     ✅ 109 issues extraídos exitosamente
#     📊 Progreso: 50.8% (61/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 62/120: Jose Miguel Bonilla - AP2
# 🔄 Procesando: TesisEnel_TuViviendaRD-JoseMiguelBonilla-Ap2
#     📄 Página 1 procesada (final), 19 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.46 segundos
#     ✅ 19 issues extraídos exitosamente
#     📊 Progreso: 51.7% (62/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 63/120: Joseph Garcia Torres - AP1
# 🔄 Procesando: TesisEnel_ProyectoFinal-JorgeToribio-Ap1
#     📄 Página 1 procesada (final), 46 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.56 segundos
#     ✅ 46 issues extraídos exitosamente
#     📊 Progreso: 52.5% (63/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 64/120: Joseph Garcia Torres - AP2
# 🔄 Procesando: TesisEnel_VerbLearn-JorgeToribio-Ap2
#     📄 Página 1 procesada (final), 76 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.38 segundos
#     ✅ 76 issues extraídos exitosamente
#     📊 Progreso: 53.3% (64/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 65/120: Josue Russo Mieses - AP1
# 🔄 Procesando: TesisEnel_ProyectoFinalCursos-josue-ap1
#     📄 Página 1 procesada (final), 88 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.53 segundos
#     ✅ 88 issues extraídos exitosamente
#     📊 Progreso: 54.2% (65/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 66/120: Josue Russo Mieses - AP2
# 🔄 Procesando: TesisEnel_ProyectoFinal_Ap2_Eventos-JosueRusso-ap2
#     📄 Página 1 procesada (final), 50 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.45 segundos
#     ✅ 50 issues extraídos exitosamente
#     📊 Progreso: 55.0% (66/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 67/120: Juan Sebastián Suarez Brito - AP1
# 🔄 Procesando: TesisEnel_VentasSyM-JuanSuarez-Ap1
#     📄 Página 1 procesada (final), 51 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.51 segundos
#     ✅ 51 issues extraídos exitosamente
#     📊 Progreso: 55.8% (67/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 68/120: Juan Sebastián Suarez Brito - AP2
# 🔄 Procesando: TesisEnel_GymApp-JuanSuarez-Ap2
#     📄 Página 1 procesada (final), 35 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.49 segundos
#     ✅ 35 issues extraídos exitosamente
#     📊 Progreso: 56.7% (68/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 69/120: Julio Cesar Pichardo Barranco - AP1
# 🔄 Procesando: TesisEnel_AguaMariaSolution-JulioPichardo-ap1
#     📄 Página 1 procesada (final), 47 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.57 segundos
#     ✅ 47 issues extraídos exitosamente
#     📊 Progreso: 57.5% (69/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 70/120: Julio Cesar Pichardo Barranco - AP2
# 🔄 Procesando: TesisEnel_CineTix-JulioPichardo-Ap2
#     📄 Página 1 procesada (final), 32 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.38 segundos
#     ✅ 32 issues extraídos exitosamente
#     📊 Progreso: 58.3% (70/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 71/120: Kevin Duran Bruno - AP1
# 🔄 Procesando: TesisEnel_ProStellar-Cesar-ap1
#     📄 Página 1 procesada (final), 285 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 1.04 segundos
#     ✅ 285 issues extraídos exitosamente
#     📊 Progreso: 59.2% (71/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 72/120: Kevin Duran Bruno - AP2
# 🔄 Procesando: TesisEnel_FlappyEnel-Cesar-ap2
#     📄 Página 1 procesada (final), 59 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.44 segundos
#     ✅ 59 issues extraídos exitosamente
#     📊 Progreso: 60.0% (72/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 73/120: Kissland Keury Baker Rodríguez - AP1
# 🔄 Procesando: TesisEnel_DealerAutos-kissland-ap1
#     📄 Página 1 procesada (final), 126 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.52 segundos
#     ✅ 126 issues extraídos exitosamente
#     📊 Progreso: 60.8% (73/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 74/120: Kissland Keury Baker Rodríguez - AP2
# 🔄 Procesando: TesisEnel_PedidosKiss-Kissland-ap2
#     📄 Página 1 procesada (final), 42 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.47 segundos
#     ✅ 42 issues extraídos exitosamente
#     📊 Progreso: 61.7% (74/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 75/120: Lisbeth Ortega peña - AP1
# 🔄 Procesando: TesisEnel_ProyectoFinal-lisbethOrtega-ap1
#     📄 Página 1 procesada (final), 68 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.47 segundos
#     ✅ 68 issues extraídos exitosamente
#     📊 Progreso: 62.5% (75/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 76/120: Lisbeth Ortega peña - AP2
# 🔄 Procesando: TesisEnel_Moonlight-Bar-LisbethOrtega-ap2
#     📄 Página 1 procesada (final), 28 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.41 segundos
#     ✅ 28 issues extraídos exitosamente
#     📊 Progreso: 63.3% (76/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 77/120: Lor Henzo Taveras Reynoso - AP1
# 🔄 Procesando: TesisEnel_GymHyR-LorHenzo-Ap1
#     📄 Página 1 procesada (final), 22 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.59 segundos
#     ✅ 22 issues extraídos exitosamente
#     📊 Progreso: 64.2% (77/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 78/120: Lor Henzo Taveras Reynoso - AP2
# 🔄 Procesando: TesisEnel_FoodiePlace-David-ap2
#     📄 Página 1 procesada (final), 66 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.56 segundos
#     ✅ 66 issues extraídos exitosamente
#     📊 Progreso: 65.0% (78/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 79/120: Luis Jose Paulino Cabrera - AP1
# 🔄 Procesando: TesisEnel_PharmaTracker-LuisJosePaulino-Ap1
#     📄 Página 1 procesada (final), 45 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.53 segundos
#     ✅ 45 issues extraídos exitosamente
#     📊 Progreso: 65.8% (79/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 80/120: Luis Jose Paulino Cabrera - AP2
# 🔄 Procesando: TesisEnel_FitnessDarck-LuisJosePaulino-Ap2
#     📄 Página 1 procesada (final), 8 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.43 segundos
#     ✅ 8 issues extraídos exitosamente
#     📊 Progreso: 66.7% (80/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 81/120: Luis Manuel Duarte - AP1
# 🔄 Procesando: TesisEnel_Proyecto_SouKuroApp-BryanOvalles-Ap1
#     📄 Página 1 procesada (final), 29 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.52 segundos
#     ✅ 29 issues extraídos exitosamente
#     📊 Progreso: 67.5% (81/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 82/120: Luis Manuel Duarte - AP2
# 🔄 Procesando: TesisEnel_FoodiePlace-David-ap2
#     📄 Página 1 procesada (final), 66 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.44 segundos
#     ✅ 66 issues extraídos exitosamente
#     📊 Progreso: 68.3% (82/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 83/120: Luis Miguel Jérez Cáceres - AP1
# 🔄 Procesando: TesisEnel_QueRecomiendas-luismiguel-ap1
#     📄 Página 1 procesada (final), 16 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.56 segundos
#     ✅ 16 issues extraídos exitosamente
#     📊 Progreso: 69.2% (83/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 84/120: Luis Miguel Jérez Cáceres - AP2
# 🔄 Procesando: TesisEnel_BodyBuilderStore-LuisMiguel-ap2
#     📄 Página 1 procesada (final), 117 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.55 segundos
#     ✅ 117 issues extraídos exitosamente
#     📊 Progreso: 70.0% (84/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 85/120: Marcos Duran De la Cruz - AP1
# 🔄 Procesando: TesisEnel_VentasSyM-JuanSuarez-Ap1
#     📄 Página 1 procesada (final), 51 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.54 segundos
#     ✅ 51 issues extraídos exitosamente
#     📊 Progreso: 70.8% (85/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 86/120: Marcos Duran De la Cruz - AP2
# 🔄 Procesando: TesisEnel_GymApp-JuanSuarez-Ap2
#     📄 Página 1 procesada (final), 35 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.45 segundos
#     ✅ 35 issues extraídos exitosamente
#     📊 Progreso: 71.7% (86/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 87/120: Miguel Angel Betances Beato - AP1
# 🔄 Procesando: TesisEnel_PanaderiaMj-JoseManuelPolanco-Ap1
#     📄 Página 1 procesada (final), 28 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.68 segundos
#     ✅ 28 issues extraídos exitosamente
#     📊 Progreso: 72.5% (87/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 88/120: Miguel Angel Betances Beato - AP2
# 🔄 Procesando: TesisEnel_Proyecto-Final-MiguelBetances-Ap2
#     📄 Página 1 procesada (final), 18 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.54 segundos
#     ✅ 18 issues extraídos exitosamente
#     📊 Progreso: 73.3% (88/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 89/120: NATHALY GORIS ESPINO - AP1
# 🔄 Procesando: TesisEnel_FinanzApp-Nathaly-Ap1
#     📄 Página 1 procesada (final), 87 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.58 segundos
#     ✅ 87 issues extraídos exitosamente
#     📊 Progreso: 74.2% (89/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 90/120: NATHALY GORIS ESPINO - AP2
# 🔄 Procesando: TesisEnel_FinanzAppMovil-Nathaly-Ap2
#     📄 Página 1 procesada (final), 24 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.46 segundos
#     ✅ 24 issues extraídos exitosamente
#     📊 Progreso: 75.0% (90/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 91/120: Pedro Vladimir Guzmán Salazar - AP1
# 🔄 Procesando: TesisEnel_Sublimation-Robelin-ap1
#     📄 Página 1 procesada (final), 24 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.87 segundos
#     ✅ 24 issues extraídos exitosamente
#     📊 Progreso: 75.8% (91/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 92/120: Pedro Vladimir Guzmán Salazar - AP2
# 🔄 Procesando: TesisEnel_SpellingAppV2-JairoAcosta-Ap2
#     📄 Página 1 procesada (final), 37 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.43 segundos
#     ✅ 37 issues extraídos exitosamente
#     📊 Progreso: 76.7% (92/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 93/120: Randy Fabián Belliard - AP1
# 🔄 Procesando: TesisEnel_GymHyR-LorHenzo-Ap1
#     📄 Página 1 procesada (final), 22 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.51 segundos
#     ✅ 22 issues extraídos exitosamente
#     📊 Progreso: 77.5% (93/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 94/120: Randy Fabián Belliard - AP2
# 🔄 Procesando: TesisEnel_PF-RandyFabian-Ap2
#     📄 Página 1 procesada (final), 39 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.43 segundos
#     ✅ 39 issues extraídos exitosamente
#     📊 Progreso: 78.3% (94/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 95/120: Reyphill Núñez Duarte - AP1
# 🔄 Procesando: TesisEnel_ReyAI_Transport-Reyfil-Ap1
#     📄 Página 1 procesada (final), 35 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.64 segundos
#     ✅ 35 issues extraídos exitosamente
#     📊 Progreso: 79.2% (95/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 96/120: Reyphill Núñez Duarte - AP2
# 🔄 Procesando: TesisEnel_NeuroPulse-Reyphill-Ap2
#     📄 Página 1 procesada (final), 22 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.41 segundos
#     ✅ 22 issues extraídos exitosamente
#     📊 Progreso: 80.0% (96/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 97/120: Robelin Isaac - AP1
# 🔄 Procesando: TesisEnel_Sublimation-Robelin-ap1
#     📄 Página 1 procesada (final), 24 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.55 segundos
#     ✅ 24 issues extraídos exitosamente
#     📊 Progreso: 80.8% (97/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 98/120: Robelin Isaac - AP2
# 🔄 Procesando: TesisEnel_SharkStyle-IsaacCoste-ap2
#     📄 Página 1 procesada (final), 78 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.38 segundos
#     ✅ 78 issues extraídos exitosamente
#     📊 Progreso: 81.7% (98/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 99/120: ROBERT DAMIAN TEJADA ORTIZ - AP1
# 🔄 Procesando: TesisEnel_Juntos_A_Suerte_Compose-Robert-ap2
#     📄 Página 1 procesada (final), 72 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.56 segundos
#     ✅ 72 issues extraídos exitosamente
#     📊 Progreso: 82.5% (99/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 100/120: ROBERT DAMIAN TEJADA ORTIZ - AP2
# 🔄 Procesando: TesisEnel_Juntos_A_Suerte_Compose-Robert-ap2
#     📄 Página 1 procesada (final), 72 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.51 segundos
#     ✅ 72 issues extraídos exitosamente
#     📊 Progreso: 83.3% (100/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 101/120: Ronell Jesús Rosario López - AP1
# 🔄 Procesando: TesisEnel_ProyectoEcommerce-Ronell-Ap1
#     📄 Página 1 procesada (final), 37 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.61 segundos
#     ✅ 37 issues extraídos exitosamente
#     📊 Progreso: 84.2% (101/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 102/120: Ronell Jesús Rosario López - AP2
# 🔄 Procesando: TesisEnel_TuRecetaApp-Samir-ap2
#     📄 Página 1 procesada (final), 28 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.45 segundos
#     ✅ 28 issues extraídos exitosamente
#     📊 Progreso: 85.0% (102/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 103/120: Ruth Betsaida - AP1
# 🔄 Procesando: TesisEnel_SwiftPay-Aaron-Ap1
#     📄 Página 1 procesada (final), 249 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.54 segundos
#     ✅ 249 issues extraídos exitosamente
#     📊 Progreso: 85.8% (103/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 104/120: Ruth Betsaida - AP2
# 🔄 Procesando: TesisEnel_DealerPOS-Aaron-ap2
#     📄 Página 1 procesada (final), 241 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.47 segundos
#     ✅ 241 issues extraídos exitosamente
#     📊 Progreso: 86.7% (104/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 105/120: Samir Ernesto Castillo Paredes - AP1
# 🔄 Procesando: TesisEnel_PharmaTracker-Samir-ap1
#     📄 Página 1 procesada (final), 45 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.53 segundos
#     ✅ 45 issues extraídos exitosamente
#     📊 Progreso: 87.5% (105/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 106/120: Samir Ernesto Castillo Paredes - AP2
# 🔄 Procesando: TesisEnel_TuRecetaApp-Samir-ap2
#     📄 Página 1 procesada (final), 28 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.45 segundos
#     ✅ 28 issues extraídos exitosamente
#     📊 Progreso: 88.3% (106/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 107/120: Samuel Antonio Javier Pantaleón - AP1
# 🔄 Procesando: TesisEnel_PeakPerformance-samuelAntonio-ap1
#     📄 Página 1 procesada (final), 56 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.46 segundos
#     ✅ 56 issues extraídos exitosamente
#     📊 Progreso: 89.2% (107/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 108/120: Samuel Antonio Javier Pantaleón - AP2
# 🔄 Procesando: TesisEnel_ProyectoFinal_Ap2-SamuelJavier-ap2
#     📄 Página 1 procesada (final), 103 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.56 segundos
#     ✅ 103 issues extraídos exitosamente
#     📊 Progreso: 90.0% (108/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 109/120: Steven Yesandy Candelario Fernández - AP1
# 🔄 Procesando: TesisEnel_ProyectoFinalAp-IsaacCoste-ap1
#     📄 Página 1 procesada (final), 54 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.56 segundos
#     ✅ 54 issues extraídos exitosamente
#     📊 Progreso: 90.8% (109/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 110/120: Steven Yesandy Candelario Fernández - AP2
# 🔄 Procesando: TesisEnel_FitGoal-Delfry-Ap2
#     📄 Página 1 procesada (final), 42 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.66 segundos
#     ✅ 42 issues extraídos exitosamente
#     📊 Progreso: 91.7% (110/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 111/120: Wilber Galvez Galvez - AP1
# 🔄 Procesando: TesisEnel_ProyectoFinalPanaderia-wilber-ap1
#     📄 Página 1 procesada (final), 60 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.55 segundos
#     ✅ 60 issues extraídos exitosamente
#     📊 Progreso: 92.5% (111/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 112/120: Wilber Galvez Galvez - AP2
# 🔄 Procesando: TesisEnel_ShopAssistant-Wilber-ap2
#     📄 Página 1 procesada (final), 36 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.56 segundos
#     ✅ 36 issues extraídos exitosamente
#     📊 Progreso: 93.3% (112/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 113/120: Yohualkis David Tejada Escolástico - AP1
# 🔄 Procesando: TesisEnel_FitForge-Yowalkis-Ap1
#     📄 Página 1 procesada (final), 57 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.54 segundos
#     ✅ 57 issues extraídos exitosamente
#     📊 Progreso: 94.2% (113/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 114/120: Yohualkis David Tejada Escolástico - AP2
# 🔄 Procesando: TesisEnel_CashControl-Yowalkis-Ap2
#     📄 Página 1 procesada (final), 37 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.58 segundos
#     ✅ 37 issues extraídos exitosamente
#     📊 Progreso: 95.0% (114/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 115/120: Yokaira Taveras Hernández - AP1
# 🔄 Procesando: TesisEnel_ProyectoFinalDotNet8-alexander-ap1
#     📄 Página 1 procesada (final), 28 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.46 segundos
#     ✅ 28 issues extraídos exitosamente
#     📊 Progreso: 95.8% (115/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 116/120: Yokaira Taveras Hernández - AP2
# 🔄 Procesando: TesisEnel_GlamourMarket-Yocaira-Ap2
#     📄 Página 1 procesada (final), 62 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.55 segundos
#     ✅ 62 issues extraídos exitosamente
#     📊 Progreso: 96.7% (116/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 117/120: Yudelka Elister Guillen - AP1
# 🔄 Procesando: TesisEnel_HydraulicFix-Delfry-Ap1
#     📄 Página 1 procesada (final), 24 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.54 segundos
#     ✅ 24 issues extraídos exitosamente
#     📊 Progreso: 97.5% (117/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 118/120: Yudelka Elister Guillen - AP2
# 🔄 Procesando: TesisEnel_FitGoal-Delfry-Ap2
#     📄 Página 1 procesada (final), 42 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.49 segundos
#     ✅ 42 issues extraídos exitosamente
#     📊 Progreso: 98.3% (118/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 119/120: Frailyn Garcia Garcia - AP1
# 🔄 Procesando: TesisEnel_FitForge-Yowalkis-Ap1
#     📄 Página 1 procesada (final), 57 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.78 segundos
#     ✅ 57 issues extraídos exitosamente
#     📊 Progreso: 99.2% (119/120)
#     ⏳ Esperando 2.0s...
#
# 📦 Proyecto 120/120: Frailyn Garcia Garcia - AP2
# 🔄 Procesando: TesisEnel_SkyFleet-FreimyHidaldo-Ap2
#     📄 Página 1 procesada (final), 3 issues encontrados
# ⏱️  fetch_project_issues ejecutado en 0.51 segundos
#     ✅ 3 issues extraídos exitosamente
#     📊 Progreso: 100.0% (120/120)
#
# 📈 Estadísticas de Extracción de Issues
# ==================================================
# ✅ Proyectos exitosos: 120 (100.0%)
# ❌ Proyectos fallidos: 0 (0.0%)
# 📊 Total de issues extraídos: 7842
# ⏱️  batch_fetch_issues ejecutado en 306.42 segundos
#
# 📈 Resultados de la extracción de issues:
# ✅ Total de proyectos procesados: 120
# ✅ Extracciones exitosas: 120
# ❌ Extracciones fallidas: 0
# 📊 Total de issues extraídos: 7842
#
# 📊 Distribución por assignment:
#   AP1: 60 proyectos, 3696 issues
#   AP2: 60 proyectos, 4146 issues
#
# 🔍 Ejemplo de issues extraídos (proyecto: TesisEnel_SwiftPay-Aaron-Ap1):
# Estudiante: Aaron Eliezer Hernández García
# Assignment: AP1
# Total de issues: 249
#
#   Issue 1:
#     Tipo: CODE_SMELL
#     Severidad: MAJOR
#     Regla: external_roslyn:CS8602
#     Línea: 206
#     Mensaje: Dereference of a possibly null reference.
#
#   Issue 2:
#     Tipo: CODE_SMELL
#     Severidad: MAJOR
#     Regla: external_roslyn:CS8602
#     Línea: 205
#     Mensaje: Dereference of a possibly null reference.
#
#   Issue 3:
#     Tipo: CODE_SMELL
#     Severidad: MAJOR
#     Regla: external_roslyn:CS8602
#     Línea: 236
#     Mensaje: Dereference of a possibly null reference.
#
# ✅ Extracción de issues completada

# %% [markdown]
# ## 5. Procesamiento y Estructuración de Datos de Issues
#
# Convertimos los resultados de la extracción en DataFrames estructurados para facilitar el análisis. A diferencia de las métricas, los issues requieren un procesamiento más complejo debido a su naturaleza detallada.
#
# ### Procesamiento realizado:
# 1. **Aplanamiento de datos**: Convertir estructura anidada en DataFrame plano
# 2. **Limpieza de mensajes**: Preparar mensajes para formato CSV
# 3. **Categorización**: Agrupar por tipo, severidad y regla
# 4. **Validación**: Verificar integridad y completitud de datos
#
# ### DataFrames generados:
# - **`df_all_issues`**: Todos los issues individuales con información completa
# - **`df_issues_summary`**: Resumen agregado por proyecto
# - **`df_issues_by_type`**: Análisis por tipo de issue (BUG, VULNERABILITY, CODE_SMELL)
# - **`df_issues_by_severity`**: Análisis por severidad (CRITICAL, MAJOR, MINOR, etc.)
#
# ### Variables de análisis:
# - Total de issues por estudiante y assignment
# - Distribución por categorías de calidad
# - Análisis de reglas más frecuentes
# - Patrones de ubicación de problemas

# %%
# Procesar y estructurar los datos extraídos de issues
print("🔄 Procesando datos de issues extraídos...")

# 1. Crear DataFrame con todos los issues individuales
all_issues_data = []

for project_result in successful_extractions:
    if project_result.get('issues'):
        all_issues_data.extend(project_result['issues'])

if all_issues_data:
    df_all_issues = pd.DataFrame(all_issues_data)
    print(f"📊 DataFrame de issues creado con {len(df_all_issues)} issues individuales")
    
    # Mostrar información básica del DataFrame
    print(f"📋 Columnas disponibles: {len(df_all_issues.columns)}")
    print(f"👥 Estudiantes únicos: {df_all_issues['student_id'].nunique()}")
    print(f"🎯 Proyectos únicos: {df_all_issues['project_key'].nunique()}")
    
    # 2. Crear resumen por proyecto
    df_issues_summary = df_all_issues.groupby([
        'student_id', 'nombre', 'project_key', 'assignment'
    ]).agg({
        'issue_key': 'count',
        'type': lambda x: x.value_counts().to_dict(),
        'severity': lambda x: x.value_counts().to_dict()
    }).reset_index()
    
    df_issues_summary.columns = ['student_id', 'nombre', 'project_key', 'assignment', 
                                'total_issues', 'types_distribution', 'severity_distribution']
    
    print(f"📈 Resumen por proyecto creado con {len(df_issues_summary)} proyectos")
    
    # 3. Análisis por tipo de issue
    type_analysis = df_all_issues.groupby(['assignment', 'type']).size().reset_index(name='count')
    type_pivot = type_analysis.pivot(index='assignment', columns='type', values='count').fillna(0)
    
    print(f"\n📊 Distribución por tipo de issue:")
    for assignment in ['AP1', 'AP2']:
        if assignment in type_pivot.index:
            print(f"  {assignment}:")
            for issue_type in type_pivot.columns:
                count = int(type_pivot.loc[assignment, issue_type])
                if count > 0:
                    print(f"    {issue_type}: {count}")
    
    # 4. Análisis por severidad
    severity_analysis = df_all_issues.groupby(['assignment', 'severity']).size().reset_index(name='count')
    severity_pivot = severity_analysis.pivot(index='assignment', columns='severity', values='count').fillna(0)
    
    print(f"\n🚨 Distribución por severidad:")
    for assignment in ['AP1', 'AP2']:
        if assignment in severity_pivot.index:
            print(f"  {assignment}:")
            for severity in severity_pivot.columns:
                count = int(severity_pivot.loc[assignment, severity])
                if count > 0:
                    print(f"    {severity}: {count}")
    
    # 5. Top 10 reglas más frecuentes
    top_rules = df_all_issues['rule'].value_counts().head(10)
    print(f"\n📋 Top 10 reglas más frecuentes:")
    for i, (rule, count) in enumerate(top_rules.items(), 1):
        print(f"  {i}. {rule}: {count} issues")
    
    # 6. Análisis de estudiantes con más issues
    student_issues = df_all_issues.groupby(['student_id', 'nombre', 'assignment']).size().reset_index(name='issues_count')
    top_students = student_issues.nlargest(10, 'issues_count')
    
    print(f"\n👥 Top 10 estudiantes con más issues:")
    for _, student in top_students.iterrows():
        print(f"  {student['nombre']} ({student['assignment']}): {student['issues_count']} issues")
    
    # 7. Mostrar muestra del DataFrame principal
    print(f"\n🔍 Primeras 3 filas del dataset de issues:")
    display(df_all_issues[['nombre', 'assignment', 'project_key', 'type', 'severity', 'rule', 'line', 'message']].head(3))
    
    # 8. Crear DataFrames específicos para análisis
    df_issues_by_type = df_all_issues.groupby(['student_id', 'nombre', 'assignment', 'type']).size().reset_index(name='count')
    df_issues_by_severity = df_all_issues.groupby(['student_id', 'nombre', 'assignment', 'severity']).size().reset_index(name='count')
    
    print(f"\n✅ DataFrames de análisis creados:")
    print(f"  📊 Issues por tipo: {len(df_issues_by_type)} filas")
    print(f"  🚨 Issues por severidad: {len(df_issues_by_severity)} filas")

else:
    print("❌ No se encontraron issues para procesar")
    df_all_issues = pd.DataFrame()
    df_issues_summary = pd.DataFrame()

print("✅ Procesamiento de datos de issues completado")
# Out:
# 🔄 Procesando datos de issues extraídos...
# 📊 DataFrame de issues creado con 7842 issues individuales
# 📋 Columnas disponibles: 18
# 👥 Estudiantes únicos: 60
# 🎯 Proyectos únicos: 78
# 📈 Resumen por proyecto creado con 120 proyectos
#
# 📊 Distribución por tipo de issue:
#   AP1:
#     BUG: 252
#     CODE_SMELL: 3411
#     VULNERABILITY: 33
#   AP2:
#     BUG: 12
#     CODE_SMELL: 4129
#     VULNERABILITY: 5
#
# 🚨 Distribución por severidad:
#   AP1:
#     BLOCKER: 39
#     CRITICAL: 197
#     INFO: 73
#     MAJOR: 1815
#     MINOR: 1572
#   AP2:
#     BLOCKER: 2
#     CRITICAL: 591
#     INFO: 80
#     MAJOR: 1194
#     MINOR: 2279
#
# 📋 Top 10 reglas más frecuentes:
#   1. kotlin:S1128: 1782 issues
#   2. csharpsquid:S1192: 831 issues
#   3. kotlin:S3776: 336 issues
#   4. kotlin:S117: 324 issues
#   5. csharpsquid:S1104: 253 issues
#   6. kotlin:S1172: 236 issues
#   7. kotlin:S1192: 217 issues
#   8. kotlin:S6619: 160 issues
#   9. csharpsquid:S6966: 160 issues
#   10. kotlin:S1481: 154 issues
#
# 👥 Top 10 estudiantes con más issues:
#   Eddy Samil Capellan Mena (AP2): 302 issues
#   Jose Daniel Rivera Ortega (AP2): 302 issues
#   Cesar Jose Reynoso Martinez (AP1): 285 issues
#   Kevin Duran Bruno (AP1): 285 issues
#   Aaron Eliezer Hernández García (AP1): 249 issues
#   Ruth Betsaida (AP1): 249 issues
#   Aaron Eliezer Hernández García (AP2): 241 issues
#   Ruth Betsaida (AP2): 241 issues
#   Kissland Keury Baker Rodríguez (AP1): 126 issues
#   Cristopher Marte Blanco (AP2): 117 issues
#
# 🔍 Primeras 3 filas del dataset de issues:
#                            nombre assignment                   project_key  \
# 0  Aaron Eliezer Hernández García        AP1  TesisEnel_SwiftPay-Aaron-Ap1
# 1  Aaron Eliezer Hernández García        AP1  TesisEnel_SwiftPay-Aaron-Ap1
# 2  Aaron Eliezer Hernández García        AP1  TesisEnel_SwiftPay-Aaron-Ap1
#
#          type severity                    rule  line  \
# 0  CODE_SMELL    MAJOR  external_roslyn:CS8602   206
# 1  CODE_SMELL    MAJOR  external_roslyn:CS8602   205
# 2  CODE_SMELL    MAJOR  external_roslyn:CS8602   236
#
#                                      message
# 0  Dereference of a possibly null reference.
# 1  Dereference of a possibly null reference.
# 2  Dereference of a possibly null reference.
# ✅ DataFrames de análisis creados:
#   📊 Issues por tipo: 191 filas
#   🚨 Issues por severidad: 447 filas
# ✅ Procesamiento de datos de issues completado

# %% [markdown]
# ## 6. Análisis Detallado por Categorías
#
# Esta sección proporciona análisis profundos de los issues extraídos organizados por diferentes categorías:
#
# 1. **Análisis por Tipo de Issue**: Distribución de BUG, CODE_SMELL, VULNERABILITY, SECURITY_HOTSPOT
# 2. **Análisis por Severidad**: Distribución de CRITICAL, MAJOR, MINOR, INFO
# 3. **Análisis por Regla**: Identificación de las reglas más violadas
# 4. **Análisis Temporal**: Comparación entre asignaciones (AP1 vs AP2)
# 5. **Análisis Estadístico**: Métricas descriptivas y correlaciones

# %%
# Análisis detallado por categorías
if not df_all_issues.empty:
    print("📊 Iniciando análisis detallado por categorías...")
    
    # 1. ANÁLISIS POR TIPO DE ISSUE
    print("\n" + "="*60)
    print("📋 ANÁLISIS POR TIPO DE ISSUE")
    print("="*60)
    
    # Distribución general por tipo
    type_counts = df_all_issues['type'].value_counts()
    total_issues = len(df_all_issues)
    
    print(f"📊 Distribución de tipos (Total: {total_issues} issues):")
    for issue_type, count in type_counts.items():
        percentage = (count / total_issues) * 100
        print(f"  {issue_type}: {count} ({percentage:.1f}%)")
    
    # Análisis por asignación
    type_by_assignment = df_all_issues.groupby(['assignment', 'type']).size().unstack(fill_value=0)
    print(f"\n📈 Distribución por asignación:")
    for assignment in type_by_assignment.index:
        total_assignment = type_by_assignment.loc[assignment].sum()
        print(f"  {assignment} (Total: {total_assignment}):")
        for issue_type in type_by_assignment.columns:
            count = type_by_assignment.loc[assignment, issue_type]
            if count > 0:
                percentage = (count / total_assignment) * 100
                print(f"    {issue_type}: {count} ({percentage:.1f}%)")
    
    # 2. ANÁLISIS POR SEVERIDAD
    print("\n" + "="*60)
    print("🚨 ANÁLISIS POR SEVERIDAD")
    print("="*60)
    
    # Distribución general por severidad
    severity_counts = df_all_issues['severity'].value_counts()
    print(f"🚨 Distribución de severidades:")
    for severity, count in severity_counts.items():
        percentage = (count / total_issues) * 100
        print(f"  {severity}: {count} ({percentage:.1f}%)")
    
    # Análisis por asignación
    severity_by_assignment = df_all_issues.groupby(['assignment', 'severity']).size().unstack(fill_value=0)
    print(f"\n📈 Distribución por asignación:")
    for assignment in severity_by_assignment.index:
        total_assignment = severity_by_assignment.loc[assignment].sum()
        print(f"  {assignment} (Total: {total_assignment}):")
        for severity in severity_by_assignment.columns:
            count = severity_by_assignment.loc[assignment, severity]
            if count > 0:
                percentage = (count / total_assignment) * 100
                print(f"    {severity}: {count} ({percentage:.1f}%)")
    
    # 3. ANÁLISIS POR REGLAS MÁS FRECUENTES
    print("\n" + "="*60)
    print("📋 ANÁLISIS POR REGLAS")
    print("="*60)
    
    # Top 15 reglas más frecuentes
    top_rules = df_all_issues['rule'].value_counts().head(15)
    print(f"📋 Top 15 reglas más violadas:")
    for i, (rule, count) in enumerate(top_rules.items(), 1):
        percentage = (count / total_issues) * 100
        print(f"  {i:2d}. {rule}: {count} ({percentage:.1f}%)")
    
    # Análisis de reglas por tipo de issue
    print(f"\n🔍 Distribución de reglas por tipo:")
    rules_by_type = df_all_issues.groupby(['type', 'rule']).size().reset_index(name='count')
    for issue_type in df_all_issues['type'].unique():
        top_rules_type = rules_by_type[rules_by_type['type'] == issue_type].nlargest(5, 'count')
        print(f"  {issue_type}:")
        for _, row in top_rules_type.iterrows():
            print(f"    {row['rule']}: {row['count']}")
    
    # 4. ANÁLISIS ESTADÍSTICO DESCRIPTIVO
    print("\n" + "="*60)
    print("📊 ANÁLISIS ESTADÍSTICO")
    print("="*60)
    
    # Issues por estudiante
    issues_per_student = df_all_issues.groupby(['student_id', 'nombre', 'assignment']).size().reset_index(name='issues_count')
    
    print(f"👥 Estadísticas de issues por estudiante:")
    for assignment in ['AP1', 'AP2']:
        assignment_data = issues_per_student[issues_per_student['assignment'] == assignment]['issues_count']
        if not assignment_data.empty:
            print(f"  {assignment}:")
            print(f"    Promedio: {assignment_data.mean():.1f}")
            print(f"    Mediana: {assignment_data.median():.1f}")
            print(f"    Desv. Estándar: {assignment_data.std():.1f}")
            print(f"    Mínimo: {assignment_data.min()}")
            print(f"    Máximo: {assignment_data.max()}")
    
    # Issues por proyecto
    issues_per_project = df_all_issues.groupby(['project_key', 'assignment']).size().reset_index(name='issues_count')
    
    print(f"\n📁 Estadísticas de issues por proyecto:")
    for assignment in ['AP1', 'AP2']:
        assignment_data = issues_per_project[issues_per_project['assignment'] == assignment]['issues_count']
        if not assignment_data.empty:
            print(f"  {assignment}:")
            print(f"    Promedio: {assignment_data.mean():.1f}")
            print(f"    Mediana: {assignment_data.median():.1f}")
            print(f"    Proyectos totales: {len(assignment_data)}")
    
    # 5. COMPARACIÓN ENTRE ASIGNACIONES
    print("\n" + "="*60)
    print("🔄 COMPARACIÓN AP1 vs AP2")
    print("="*60)
    
    ap1_issues = df_all_issues[df_all_issues['assignment'] == 'AP1']
    ap2_issues = df_all_issues[df_all_issues['assignment'] == 'AP2']
    
    print(f"📊 Resumen comparativo:")
    print(f"  AP1: {len(ap1_issues)} issues en {ap1_issues['project_key'].nunique()} proyectos")
    print(f"  AP2: {len(ap2_issues)} issues en {ap2_issues['project_key'].nunique()} proyectos")
    
    if len(ap1_issues) > 0 and len(ap2_issues) > 0:
        print(f"  Promedio issues/proyecto:")
        print(f"    AP1: {len(ap1_issues) / ap1_issues['project_key'].nunique():.1f}")
        print(f"    AP2: {len(ap2_issues) / ap2_issues['project_key'].nunique():.1f}")
    
    print("\n✅ Análisis detallado completado")
    
else:
    print("❌ No hay datos de issues disponibles para el análisis")
# Out:
# 📊 Iniciando análisis detallado por categorías...
#
# ============================================================
# 📋 ANÁLISIS POR TIPO DE ISSUE
# ============================================================
# 📊 Distribución de tipos (Total: 7842 issues):
#   CODE_SMELL: 7540 (96.1%)
#   BUG: 264 (3.4%)
#   VULNERABILITY: 38 (0.5%)
#
# 📈 Distribución por asignación:
#   AP1 (Total: 3696):
#     BUG: 252 (6.8%)
#     CODE_SMELL: 3411 (92.3%)
#     VULNERABILITY: 33 (0.9%)
#   AP2 (Total: 4146):
#     BUG: 12 (0.3%)
#     CODE_SMELL: 4129 (99.6%)
#     VULNERABILITY: 5 (0.1%)
#
# ============================================================
# 🚨 ANÁLISIS POR SEVERIDAD
# ============================================================
# 🚨 Distribución de severidades:
#   MINOR: 3851 (49.1%)
#   MAJOR: 3009 (38.4%)
#   CRITICAL: 788 (10.0%)
#   INFO: 153 (2.0%)
#   BLOCKER: 41 (0.5%)
#
# 📈 Distribución por asignación:
#   AP1 (Total: 3696):
#     BLOCKER: 39 (1.1%)
#     CRITICAL: 197 (5.3%)
#     INFO: 73 (2.0%)
#     MAJOR: 1815 (49.1%)
#     MINOR: 1572 (42.5%)
#   AP2 (Total: 4146):
#     BLOCKER: 2 (0.0%)
#     CRITICAL: 591 (14.3%)
#     INFO: 80 (1.9%)
#     MAJOR: 1194 (28.8%)
#     MINOR: 2279 (55.0%)
#
# ============================================================
# 📋 ANÁLISIS POR REGLAS
# ============================================================
# 📋 Top 15 reglas más violadas:
#    1. kotlin:S1128: 1782 (22.7%)
#    2. csharpsquid:S1192: 831 (10.6%)
#    3. kotlin:S3776: 336 (4.3%)
#    4. kotlin:S117: 324 (4.1%)
#    5. csharpsquid:S1104: 253 (3.2%)
#    6. kotlin:S1172: 236 (3.0%)
#    7. kotlin:S1192: 217 (2.8%)
#    8. kotlin:S6619: 160 (2.0%)
#    9. csharpsquid:S6966: 160 (2.0%)
#   10. kotlin:S1481: 154 (2.0%)
#   11. kotlin:S6518: 142 (1.8%)
#   12. azureresourcemanager:S6975: 126 (1.6%)
#   13. css:S4666: 123 (1.6%)
#   14. external_roslyn:CS8602: 119 (1.5%)
#   15. kotlin:S107: 119 (1.5%)
#
# 🔍 Distribución de reglas por tipo:
#   CODE_SMELL:
#     kotlin:S1128: 1782
#     csharpsquid:S1192: 831
#     kotlin:S3776: 336
#     kotlin:S117: 324
#     csharpsquid:S1104: 253
#   BUG:
#     csharpsquid:S3903: 114
#     csharpsquid:S2259: 31
#     css:S4656: 26
#     csharpsquid:S2583: 23
#     Web:S5254: 10
#   VULNERABILITY:
#     secrets:S6703: 28
#     roslyn.sonaranalyzer.security.cs:S5146: 4
#     kotlin:S7204: 3
#     secrets:S6334: 2
#     csharpsquid:S6781: 1
#
# ============================================================
# 📊 ANÁLISIS ESTADÍSTICO
# ============================================================
# 👥 Estadísticas de issues por estudiante:
#   AP1:
#     Promedio: 61.6
#     Mediana: 45.0
#     Desv. Estándar: 59.7
#     Mínimo: 16
#     Máximo: 285
#   AP2:
#     Promedio: 69.1
#     Mediana: 43.0
#     Desv. Estándar: 63.8
#     Mínimo: 3
#     Máximo: 302
#
# 📁 Estadísticas de issues por proyecto:
#   AP1:
#     Promedio: 94.8
#     Mediana: 70.0
#     Proyectos totales: 39
#   AP2:
#     Promedio: 103.7
#     Mediana: 58.5
#     Proyectos totales: 40
#
# ============================================================
# 🔄 COMPARACIÓN AP1 vs AP2
# ============================================================
# 📊 Resumen comparativo:
#   AP1: 3696 issues en 39 proyectos
#   AP2: 4146 issues en 40 proyectos
#   Promedio issues/proyecto:
#     AP1: 94.8
#     AP2: 103.7
#
# ✅ Análisis detallado completado

# %% [markdown]
# ## 7. Exportar Datos de Issues
#
# Esta sección se encarga de exportar los datos extraídos y procesados a archivos CSV para su uso posterior:
#
# 1. **Issues Individuales**: Archivo con todos los issues detallados
# 2. **Resumen por Proyecto**: Consolidado con conteos y distribuciones
# 3. **Análisis por Tipo**: Distribución de tipos de issues por estudiante/proyecto
# 4. **Análisis por Severidad**: Distribución de severidades por estudiante/proyecto
# 5. **Metadatos de Extracción**: Información sobre el proceso de extracción

# %%
# Exportar datos de issues a archivos CSV
import os
from datetime import datetime

# Crear directorio data si no existe
os.makedirs('../data', exist_ok=True)

# Timestamp para archivos
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

if not df_all_issues.empty:
    print("📁 Exportando datos de issues...")
    
    try:
        # 1. EXPORTAR ISSUES INDIVIDUALES COMPLETOS
        issues_filename = f'../data/issues_detallados_{timestamp}.csv'
        df_all_issues.to_csv(issues_filename, index=False, encoding='utf-8-sig')
        print(f"✅ Issues individuales exportados: {issues_filename}")
        print(f"   📊 {len(df_all_issues)} issues de {df_all_issues['student_id'].nunique()} estudiantes")
        
        # 2. EXPORTAR RESUMEN POR PROYECTO
        if not df_issues_summary.empty:
            summary_filename = f'../data/issues_resumen_proyecto_{timestamp}.csv'
            df_issues_summary.to_csv(summary_filename, index=False, encoding='utf-8-sig')
            print(f"✅ Resumen por proyecto exportado: {summary_filename}")
            print(f"   📊 {len(df_issues_summary)} proyectos")
        
        # 3. EXPORTAR ANÁLISIS POR TIPO
        if 'df_issues_by_type' in locals():
            type_filename = f'../data/issues_por_tipo_{timestamp}.csv'
            df_issues_by_type.to_csv(type_filename, index=False, encoding='utf-8-sig')
            print(f"✅ Análisis por tipo exportado: {type_filename}")
            print(f"   📊 {len(df_issues_by_type)} registros")
        
        # 4. EXPORTAR ANÁLISIS POR SEVERIDAD
        if 'df_issues_by_severity' in locals():
            severity_filename = f'../data/issues_por_severidad_{timestamp}.csv'
            df_issues_by_severity.to_csv(severity_filename, index=False, encoding='utf-8-sig')
            print(f"✅ Análisis por severidad exportado: {severity_filename}")
            print(f"   📊 {len(df_issues_by_severity)} registros")
        
        # 5. CREAR ARCHIVO DE ESTADÍSTICAS RESUMIDAS
        stats_data = []
        
        # Estadísticas generales
        stats_data.append({
            'categoria': 'General',
            'metrica': 'Total Issues',
            'valor': len(df_all_issues),
            'descripcion': 'Número total de issues extraídos'
        })
        
        stats_data.append({
            'categoria': 'General',
            'metrica': 'Estudiantes Únicos',
            'valor': df_all_issues['student_id'].nunique(),
            'descripcion': 'Número de estudiantes con issues'
        })
        
        stats_data.append({
            'categoria': 'General',
            'metrica': 'Proyectos Únicos',
            'valor': df_all_issues['project_key'].nunique(),
            'descripcion': 'Número de proyectos con issues'
        })
        
        # Estadísticas por asignación
        for assignment in ['AP1', 'AP2']:
            assignment_issues = df_all_issues[df_all_issues['assignment'] == assignment]
            if not assignment_issues.empty:
                stats_data.append({
                    'categoria': assignment,
                    'metrica': 'Total Issues',
                    'valor': len(assignment_issues),
                    'descripcion': f'Issues en {assignment}'
                })
                
                stats_data.append({
                    'categoria': assignment,
                    'metrica': 'Proyectos',
                    'valor': assignment_issues['project_key'].nunique(),
                    'descripcion': f'Proyectos con issues en {assignment}'
                })
                
                stats_data.append({
                    'categoria': assignment,
                    'metrica': 'Promedio Issues/Proyecto',
                    'valor': round(len(assignment_issues) / assignment_issues['project_key'].nunique(), 2),
                    'descripcion': f'Promedio de issues por proyecto en {assignment}'
                })
        
        # Estadísticas por tipo de issue
        type_counts = df_all_issues['type'].value_counts()
        for issue_type, count in type_counts.items():
            stats_data.append({
                'categoria': 'Tipos',
                'metrica': issue_type,
                'valor': count,
                'descripcion': f'Issues de tipo {issue_type}'
            })
        
        # Estadísticas por severidad
        severity_counts = df_all_issues['severity'].value_counts()
        for severity, count in severity_counts.items():
            stats_data.append({
                'categoria': 'Severidad',
                'metrica': severity,
                'valor': count,
                'descripcion': f'Issues con severidad {severity}'
            })
        
        # Exportar estadísticas
        df_stats = pd.DataFrame(stats_data)
        stats_filename = f'../data/issues_estadisticas_{timestamp}.csv'
        df_stats.to_csv(stats_filename, index=False, encoding='utf-8-sig')
        print(f"✅ Estadísticas exportadas: {stats_filename}")
        print(f"   📊 {len(df_stats)} métricas estadísticas")
        
        # 6. CREAR ARCHIVO DE METADATOS
        metadata = {
            'fecha_extraccion': datetime.now().isoformat(),
            'total_estudiantes_procesados': len(df_estudiantes) if 'df_estudiantes' in locals() else 0,
            'total_proyectos_intentados': len(successful_extractions) + len(failed_extractions) if 'successful_extractions' in locals() and 'failed_extractions' in locals() else 0,
            'total_proyectos_exitosos': len(successful_extractions) if 'successful_extractions' in locals() else 0,
            'total_proyectos_fallidos': len(failed_extractions) if 'failed_extractions' in locals() else 0,
            'total_issues_extraidos': len(df_all_issues),
            'estudiantes_con_issues': df_all_issues['student_id'].nunique(),
            'proyectos_con_issues': df_all_issues['project_key'].nunique(),
            'archivos_generados': [
                issues_filename,
                summary_filename if not df_issues_summary.empty else None,
                type_filename if 'df_issues_by_type' in locals() else None,
                severity_filename if 'df_issues_by_severity' in locals() else None,
                stats_filename
            ]
        }
        
        # Filtrar archivos None
        metadata['archivos_generados'] = [f for f in metadata['archivos_generados'] if f is not None]
        
        metadata_filename = f'../data/issues_metadata_{timestamp}.json'
        import json
        with open(metadata_filename, 'w', encoding='utf-8') as f:
            json.dump(metadata, f, indent=2, ensure_ascii=False)
        
        print(f"✅ Metadatos exportados: {metadata_filename}")
        
        # RESUMEN FINAL
        print(f"\n" + "="*60)
        print("📋 RESUMEN DE EXPORTACIÓN")
        print("="*60)
        print(f"🕒 Fecha: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
        print(f"📊 Issues exportados: {len(df_all_issues)}")
        print(f"👥 Estudiantes: {df_all_issues['student_id'].nunique()}")
        print(f"📁 Proyectos: {df_all_issues['project_key'].nunique()}")
        print(f"📄 Archivos generados: {len(metadata['archivos_generados'])}")
        print(f"\n📁 Archivos guardados en: ../data/")
        for archivo in metadata['archivos_generados']:
            print(f"   • {os.path.basename(archivo)}")
        
        # También crear una versión simplificada sin timestamp para facilitar el acceso
        main_filename = '../data/issues_detallados_latest.csv'
        df_all_issues.to_csv(main_filename, index=False, encoding='utf-8-sig')
        print(f"\n✅ Archivo principal actualizado: {main_filename}")
        
    except Exception as e:
        print(f"❌ Error durante la exportación: {str(e)}")
        logging.error(f"Error en exportación: {str(e)}")

else:
    print("❌ No hay datos de issues para exportar")

print("\n🎉 Proceso de extracción de issues completado!")
# Out:
# 📁 Exportando datos de issues...
# ✅ Issues individuales exportados: ../data/issues_detallados_20250803_203916.csv
#    📊 7842 issues de 60 estudiantes
# ✅ Resumen por proyecto exportado: ../data/issues_resumen_proyecto_20250803_203916.csv
#    📊 120 proyectos
# ✅ Análisis por tipo exportado: ../data/issues_por_tipo_20250803_203916.csv
#    📊 191 registros
# ✅ Análisis por severidad exportado: ../data/issues_por_severidad_20250803_203916.csv
#    📊 447 registros
# ✅ Estadísticas exportadas: ../data/issues_estadisticas_20250803_203916.csv
#    📊 17 métricas estadísticas
# ✅ Metadatos exportados: ../data/issues_metadata_20250803_203916.json
#
# ============================================================
# 📋 RESUMEN DE EXPORTACIÓN
# ============================================================
# 🕒 Fecha: 2025-08-03 20:39:16
# 📊 Issues exportados: 7842
# 👥 Estudiantes: 60
# 📁 Proyectos: 78
# 📄 Archivos generados: 5
#
# 📁 Archivos guardados en: ../data/
#    • issues_detallados_20250803_203916.csv
#    • issues_resumen_proyecto_20250803_203916.csv
#    • issues_por_tipo_20250803_203916.csv
#    • issues_por_severidad_20250803_203916.csv
#    • issues_estadisticas_20250803_203916.csv
#
# ✅ Archivo principal actualizado: ../data/issues_detallados_latest.csv
#
# 🎉 Proceso de extracción de issues completado!

# %% [markdown]
# ## 📋 Resumen del Notebook
#
# Este notebook ha completado exitosamente la extracción y análisis de issues de SonarCloud para los proyectos de estudiantes.
#
# ### ✅ Procesos Realizados:
#
# 1. **Configuración**: Setup de APIs y credenciales de SonarCloud
# 2. **Carga de Datos**: Lectura de información de estudiantes y proyectos
# 3. **Extracción**: Obtención de issues detallados usando la API de SonarCloud
# 4. **Procesamiento**: Estructuración y análisis de los datos extraídos
# 5. **Análisis**: Categorización por tipo, severidad, reglas y comparaciones
# 6. **Exportación**: Generación de múltiples archivos CSV para análisis posterior
#
# ### 📊 Datos Generados:
#
# - **Issues Detallados**: Cada issue individual con toda su información
# - **Resumen por Proyecto**: Consolidación de issues por proyecto y estudiante
# - **Análisis por Categorías**: Distribuciones por tipo y severidad
# - **Estadísticas**: Métricas descriptivas y comparativas
# - **Metadatos**: Información del proceso de extracción
#
# ### 🔄 Próximos Pasos:
#
# 1. Utilizar los archivos CSV generados para análisis estadísticos avanzados
# 2. Combinar con datos de métricas de calidad para análisis integral
# 3. Generar visualizaciones y reportes de calidad de software
# 4. Identificar patrones y tendencias en los tipos de issues más comunes
#
# ---
# *Notebook creado para el análisis de calidad de software en proyectos estudiantiles - Tesis Aplicada 2*
